# %% [markdown]
# <a href="https://colab.research.google.com/github/ispapadakis/cifar10/blob/master/CIFAR_10_RESNETv1b_No_Noise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIFAR-10 Analysis - No Noise
#
# ---
#
# - Architecture: Resnet
# - Data Augmentation: Horizontal Flip, Rotate, Shift, Zoom
# - Config B: New LR Schedule
#
# <p> Based On: https://github.com/keras-team/keras/blob/master/examples/cifar10_resnet.py

# %% [markdown]
# # Load Data and Libraries

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10

import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
# Out:
# Using TensorFlow backend.

# %%
# Training parameters
batch_size = 128  # orig paper trained all networks with batch_size=128
epochs = 100
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# %%
n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# %%
# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 24s 0us/step

# %%
# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# # Model Architecture

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder
    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)
    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]
    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M
    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]
    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256
    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule
    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.
    # Arguments
        epoch (int): The number of epochs
    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 90:
        lr *= 0.03
    elif epoch > 80:
        lr *= 0.1
    elif epoch > 60:
        lr *= 0.2
    elif epoch > 40:
        lr *= 0.5
    print('Learning rate: ', lr)
    return lr

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Learning rate:  0.001
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 16)   0           activation_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 16)   2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 16)   64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 16)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 16)   2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 16)   0           activation_3[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 16)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 16)   2320        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 16)   64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 16)   0           activation_5[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 16)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 32)   4640        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 32)   128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 32)   544         activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 32)   0           conv2d_10[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 32)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 32)   9248        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 32)   9248        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 32)   128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 32)   0           activation_9[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 32)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 32)   9248        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 32)   128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 32)   9248        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 32)   128         conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 32)   0           activation_11[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 32)   0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 64)     18496       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 64)     256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 64)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 64)     36928       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 64)     2112        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 64)     256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 64)     0           conv2d_17[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 64)     0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 64)     36928       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 64)     256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 64)     0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 64)     36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 8, 8, 64)     256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 64)     0           activation_15[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 64)     0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 64)     36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 64)     256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 64)     0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 64)     36928       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 64)     256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 8, 64)     0           activation_17[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 64)     0           add_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 64)     0           activation_19[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 64)           0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           650         flatten_1[0][0]
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# ResNet20v1

# %% [markdown]
# # Train Model

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
fname = 'cifar10-resnet{}-best.h5'.format(version)
checkpoint = ModelCheckpoint(filepath=fname,
                             monitor='val_acc', verbose=2, 
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    zoom_range=[0.8,1.4],
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False
    )
datagen.fit(x_train)

# %%
# Fit the model on the batches generated by datagen.flow().
hist = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=2*x_train.shape[0]//batch_size,
                    validation_data=(x_test, y_test),
                    epochs=epochs, verbose=2, callbacks=callbacks)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# Learning rate:  0.001
#  - 88s - loss: 1.6725 - acc: 0.4541 - val_loss: 1.3960 - val_acc: 0.5482
#
# Epoch 00001: val_acc improved from -inf to 0.54820, saving model to cifar10-resnet1-best.h5
# Epoch 2/100
# Learning rate:  0.001
#  - 81s - loss: 1.2392 - acc: 0.6097 - val_loss: 1.5096 - val_acc: 0.5746
#
# Epoch 00002: val_acc improved from 0.54820 to 0.57460, saving model to cifar10-resnet1-best.h5
# Epoch 3/100
# Learning rate:  0.001
#  - 80s - loss: 1.0677 - acc: 0.6740 - val_loss: 1.0329 - val_acc: 0.6844
#
# Epoch 00003: val_acc improved from 0.57460 to 0.68440, saving model to cifar10-resnet1-best.h5
# Epoch 4/100
# Learning rate:  0.001
#  - 80s - loss: 0.9597 - acc: 0.7117 - val_loss: 0.9659 - val_acc: 0.7179
#
# Epoch 00004: val_acc improved from 0.68440 to 0.71790, saving model to cifar10-resnet1-best.h5
# Epoch 5/100
# Learning rate:  0.001
#  - 80s - loss: 0.8889 - acc: 0.7370 - val_loss: 0.9740 - val_acc: 0.7285
#
# Epoch 00005: val_acc improved from 0.71790 to 0.72850, saving model to cifar10-resnet1-best.h5
# Epoch 6/100
# Learning rate:  0.001
#  - 80s - loss: 0.8335 - acc: 0.7579 - val_loss: 0.9481 - val_acc: 0.7422
#
# Epoch 00006: val_acc improved from 0.72850 to 0.74220, saving model to cifar10-resnet1-best.h5
# Epoch 7/100
# Learning rate:  0.001
#  - 80s - loss: 0.7887 - acc: 0.7732 - val_loss: 1.1327 - val_acc: 0.6899
#
# Epoch 00007: val_acc did not improve from 0.74220
# Epoch 8/100
# Learning rate:  0.001
#  - 80s - loss: 0.7583 - acc: 0.7844 - val_loss: 0.7302 - val_acc: 0.7940
#
# Epoch 00008: val_acc improved from 0.74220 to 0.79400, saving model to cifar10-resnet1-best.h5
# Epoch 9/100
# Learning rate:  0.001
#  - 80s - loss: 0.7301 - acc: 0.7948 - val_loss: 0.8296 - val_acc: 0.7765
#
# Epoch 00009: val_acc did not improve from 0.79400
# Epoch 10/100
# Learning rate:  0.001
#  - 80s - loss: 0.7027 - acc: 0.8042 - val_loss: 0.9750 - val_acc: 0.7416
#
# Epoch 00010: val_acc did not improve from 0.79400
# Epoch 11/100
# Learning rate:  0.001
#  - 80s - loss: 0.6815 - acc: 0.8122 - val_loss: 0.7892 - val_acc: 0.7920
#
# Epoch 00011: val_acc did not improve from 0.79400
# Epoch 12/100
# Learning rate:  0.001
#  - 80s - loss: 0.6706 - acc: 0.8157 - val_loss: 0.7943 - val_acc: 0.7910
#
# Epoch 00012: val_acc did not improve from 0.79400
# Epoch 13/100
# Learning rate:  0.001
#  - 80s - loss: 0.6541 - acc: 0.8239 - val_loss: 0.7769 - val_acc: 0.7812
#
# Epoch 00013: val_acc did not improve from 0.79400
# Epoch 14/100
# Learning rate:  0.001
#  - 80s - loss: 0.6404 - acc: 0.8277 - val_loss: 0.8821 - val_acc: 0.7784
#
# Epoch 00014: val_acc did not improve from 0.79400
# Epoch 15/100
# Learning rate:  0.001
#  - 80s - loss: 0.6253 - acc: 0.8338 - val_loss: 0.6983 - val_acc: 0.8169
#
# Epoch 00015: val_acc improved from 0.79400 to 0.81690, saving model to cifar10-resnet1-best.h5
# Epoch 16/100
# Learning rate:  0.001
#  - 80s - loss: 0.6188 - acc: 0.8352 - val_loss: 0.6367 - val_acc: 0.8374
#
# Epoch 00016: val_acc improved from 0.81690 to 0.83740, saving model to cifar10-resnet1-best.h5
# Epoch 17/100
# Learning rate:  0.001
#  - 80s - loss: 0.6051 - acc: 0.8402 - val_loss: 1.0583 - val_acc: 0.7543
#
# Epoch 00017: val_acc did not improve from 0.83740
# Epoch 18/100
# Learning rate:  0.001
#  - 80s - loss: 0.5969 - acc: 0.8435 - val_loss: 0.8391 - val_acc: 0.7968
#
# Epoch 00018: val_acc did not improve from 0.83740
# Epoch 19/100
# Learning rate:  0.001
#  - 80s - loss: 0.5869 - acc: 0.8480 - val_loss: 0.7250 - val_acc: 0.8193
#
# Epoch 00019: val_acc did not improve from 0.83740
# Epoch 20/100
# Learning rate:  0.001
#  - 80s - loss: 0.5842 - acc: 0.8474 - val_loss: 0.8520 - val_acc: 0.7792
#
# Epoch 00020: val_acc did not improve from 0.83740
# Epoch 21/100
# Learning rate:  0.001
#  - 80s - loss: 0.5770 - acc: 0.8514 - val_loss: 0.8390 - val_acc: 0.8002
#
# Epoch 00021: val_acc did not improve from 0.83740
# Epoch 22/100
# Learning rate:  0.001
#  - 79s - loss: 0.5673 - acc: 0.8539 - val_loss: 0.6902 - val_acc: 0.8278
#
# Epoch 00022: val_acc did not improve from 0.83740
# Epoch 23/100
# Learning rate:  0.001
#  - 80s - loss: 0.5634 - acc: 0.8555 - val_loss: 0.7581 - val_acc: 0.8099
#
# Epoch 00023: val_acc did not improve from 0.83740
# Epoch 24/100
# Learning rate:  0.001
#  - 80s - loss: 0.5568 - acc: 0.8592 - val_loss: 0.9661 - val_acc: 0.7646
#
# Epoch 00024: val_acc did not improve from 0.83740
# Epoch 25/100
# Learning rate:  0.001
#  - 79s - loss: 0.5502 - acc: 0.8621 - val_loss: 0.6416 - val_acc: 0.8432
#
# Epoch 00025: val_acc improved from 0.83740 to 0.84320, saving model to cifar10-resnet1-best.h5
# Epoch 26/100
# Learning rate:  0.001
#  - 80s - loss: 0.5457 - acc: 0.8636 - val_loss: 0.6795 - val_acc: 0.8380
#
# Epoch 00026: val_acc did not improve from 0.84320
# Epoch 27/100
# Learning rate:  0.001
#  - 80s - loss: 0.5437 - acc: 0.8630 - val_loss: 0.7649 - val_acc: 0.8183
#
# Epoch 00027: val_acc did not improve from 0.84320
# Epoch 28/100
# Learning rate:  0.001
#  - 80s - loss: 0.5395 - acc: 0.8644 - val_loss: 0.6205 - val_acc: 0.8497
#
# Epoch 00028: val_acc improved from 0.84320 to 0.84970, saving model to cifar10-resnet1-best.h5
# Epoch 29/100
# Learning rate:  0.001
#  - 80s - loss: 0.5365 - acc: 0.8663 - val_loss: 0.5943 - val_acc: 0.8507
#
# Epoch 00029: val_acc improved from 0.84970 to 0.85070, saving model to cifar10-resnet1-best.h5
# Epoch 30/100
# Learning rate:  0.001
#  - 79s - loss: 0.5356 - acc: 0.8668 - val_loss: 0.7482 - val_acc: 0.8098
#
# Epoch 00030: val_acc did not improve from 0.85070
# Epoch 31/100
# Learning rate:  0.001
#  - 79s - loss: 0.5295 - acc: 0.8693 - val_loss: 0.6628 - val_acc: 0.8328
#
# Epoch 00031: val_acc did not improve from 0.85070
# Epoch 32/100
# Learning rate:  0.001
#  - 79s - loss: 0.5236 - acc: 0.8712 - val_loss: 0.6266 - val_acc: 0.8506
#
# Epoch 00032: val_acc did not improve from 0.85070
# Epoch 33/100
# Learning rate:  0.001
#  - 79s - loss: 0.5181 - acc: 0.8729 - val_loss: 0.6281 - val_acc: 0.8411
#
# Epoch 00033: val_acc did not improve from 0.85070
# Epoch 34/100
# Learning rate:  0.001
#  - 80s - loss: 0.5210 - acc: 0.8731 - val_loss: 0.7290 - val_acc: 0.8331
#
# Epoch 00034: val_acc did not improve from 0.85070
# Epoch 35/100
# Learning rate:  0.001
#  - 80s - loss: 0.5125 - acc: 0.8750 - val_loss: 0.6688 - val_acc: 0.8350
#
# Epoch 00035: val_acc did not improve from 0.85070
# Epoch 36/100
# Learning rate:  0.001
#  - 80s - loss: 0.5124 - acc: 0.8755 - val_loss: 0.6514 - val_acc: 0.8452
#
# Epoch 00036: val_acc did not improve from 0.85070
# Epoch 37/100
# Learning rate:  0.001
#  - 80s - loss: 0.5115 - acc: 0.8763 - val_loss: 0.7852 - val_acc: 0.8145
#
# Epoch 00037: val_acc did not improve from 0.85070
# Epoch 38/100
# Learning rate:  0.001
#  - 80s - loss: 0.5133 - acc: 0.8754 - val_loss: 0.6005 - val_acc: 0.8575
#
# Epoch 00038: val_acc improved from 0.85070 to 0.85750, saving model to cifar10-resnet1-best.h5
# Epoch 39/100
# Learning rate:  0.001
#  - 80s - loss: 0.5023 - acc: 0.8783 - val_loss: 0.6997 - val_acc: 0.8342
#
# Epoch 00039: val_acc did not improve from 0.85750
# Epoch 40/100
# Learning rate:  0.001
#  - 80s - loss: 0.5055 - acc: 0.8783 - val_loss: 0.7237 - val_acc: 0.8320
#
# Epoch 00040: val_acc did not improve from 0.85750
# Epoch 41/100
# Learning rate:  0.001
#  - 80s - loss: 0.5021 - acc: 0.8795 - val_loss: 0.6463 - val_acc: 0.8463
#
# Epoch 00041: val_acc did not improve from 0.85750
# Epoch 42/100
# Learning rate:  0.0005
#  - 79s - loss: 0.4403 - acc: 0.9011 - val_loss: 0.5229 - val_acc: 0.8819
#
# Epoch 00042: val_acc improved from 0.85750 to 0.88190, saving model to cifar10-resnet1-best.h5
# Epoch 43/100
# Learning rate:  0.0005
#  - 79s - loss: 0.4238 - acc: 0.9040 - val_loss: 0.5161 - val_acc: 0.8818
#
# Epoch 00043: val_acc did not improve from 0.88190
# Epoch 44/100
# Learning rate:  0.0005
#  - 80s - loss: 0.4196 - acc: 0.9045 - val_loss: 0.5536 - val_acc: 0.8758
#
# Epoch 00044: val_acc did not improve from 0.88190
# Epoch 45/100
# Learning rate:  0.0005
#  - 79s - loss: 0.4107 - acc: 0.9064 - val_loss: 0.5199 - val_acc: 0.8817
#
# Epoch 00045: val_acc did not improve from 0.88190
# Epoch 46/100
# Learning rate:  0.0005
#  - 79s - loss: 0.4070 - acc: 0.9065 - val_loss: 0.5597 - val_acc: 0.8724
#
# Epoch 00046: val_acc did not improve from 0.88190
# Epoch 47/100
# Learning rate:  0.0005
#  - 79s - loss: 0.4004 - acc: 0.9078 - val_loss: 0.5942 - val_acc: 0.8560
#
# Epoch 00047: val_acc did not improve from 0.88190
# Epoch 48/100
# Learning rate:  0.0005
#  - 79s - loss: 0.4007 - acc: 0.9071 - val_loss: 0.5631 - val_acc: 0.8701
#
# Epoch 00048: val_acc did not improve from 0.88190
# Epoch 49/100
# Learning rate:  0.0005
#  - 79s - loss: 0.3914 - acc: 0.9100 - val_loss: 0.5173 - val_acc: 0.8828
#
# Epoch 00049: val_acc improved from 0.88190 to 0.88280, saving model to cifar10-resnet1-best.h5
# Epoch 50/100
# Learning rate:  0.0005
#  - 79s - loss: 0.3863 - acc: 0.9106 - val_loss: 0.5521 - val_acc: 0.8703
#
# Epoch 00050: val_acc did not improve from 0.88280
# Epoch 51/100
# Learning rate:  0.0005
#  - 80s - loss: 0.3881 - acc: 0.9100 - val_loss: 0.5271 - val_acc: 0.8741
#
# Epoch 00051: val_acc did not improve from 0.88280
# Epoch 52/100
# Learning rate:  0.0005
#  - 80s - loss: 0.3823 - acc: 0.9116 - val_loss: 0.6198 - val_acc: 0.8605
#
# Epoch 00052: val_acc did not improve from 0.88280
# Epoch 53/100
# Learning rate:  0.0005
#  - 80s - loss: 0.3812 - acc: 0.9117 - val_loss: 0.4647 - val_acc: 0.8936
#
# Epoch 00053: val_acc improved from 0.88280 to 0.89360, saving model to cifar10-resnet1-best.h5
# Epoch 54/100
# Learning rate:  0.0005
#  - 79s - loss: 0.3783 - acc: 0.9126 - val_loss: 0.5454 - val_acc: 0.8724
#
# Epoch 00054: val_acc did not improve from 0.89360
# Epoch 55/100
# Learning rate:  0.0005
#  - 80s - loss: 0.3768 - acc: 0.9111 - val_loss: 0.5348 - val_acc: 0.8779
#
# Epoch 00055: val_acc did not improve from 0.89360
# Epoch 56/100
# Learning rate:  0.0005
#  - 79s - loss: 0.3755 - acc: 0.9123 - val_loss: 0.5169 - val_acc: 0.8748
#
# Epoch 00056: val_acc did not improve from 0.89360
# Epoch 57/100
# Learning rate:  0.0005
#  - 80s - loss: 0.3743 - acc: 0.9128 - val_loss: 0.5884 - val_acc: 0.8629
#
# Epoch 00057: val_acc did not improve from 0.89360
# Epoch 58/100
# Learning rate:  0.0005
#  - 80s - loss: 0.3670 - acc: 0.9152 - val_loss: 0.5782 - val_acc: 0.8697
#
# Epoch 00058: val_acc did not improve from 0.89360
# Epoch 59/100
# Learning rate:  0.0005
#  - 86s - loss: 0.3689 - acc: 0.9138 - val_loss: 0.5376 - val_acc: 0.8739
#
# Epoch 00059: val_acc did not improve from 0.89360
# Epoch 60/100
# Learning rate:  0.0005
#  - 95s - loss: 0.3674 - acc: 0.9140 - val_loss: 0.5452 - val_acc: 0.8786
#
# Epoch 00060: val_acc did not improve from 0.89360
# Epoch 61/100
# Learning rate:  0.0005
#  - 95s - loss: 0.3667 - acc: 0.9142 - val_loss: 0.4967 - val_acc: 0.8853
#
# Epoch 00061: val_acc did not improve from 0.89360
# Epoch 62/100
# Learning rate:  0.0002
#  - 94s - loss: 0.3213 - acc: 0.9305 - val_loss: 0.4314 - val_acc: 0.9058
#
# Epoch 00062: val_acc improved from 0.89360 to 0.90580, saving model to cifar10-resnet1-best.h5
# Epoch 63/100
# Learning rate:  0.0002
#  - 93s - loss: 0.3110 - acc: 0.9330 - val_loss: 0.4230 - val_acc: 0.9043
#
# Epoch 00063: val_acc did not improve from 0.90580
# Epoch 64/100
# Learning rate:  0.0002
#  - 91s - loss: 0.3084 - acc: 0.9337 - val_loss: 0.4524 - val_acc: 0.8974
#
# Epoch 00064: val_acc did not improve from 0.90580
# Epoch 65/100
# Learning rate:  0.0002
#  - 79s - loss: 0.3035 - acc: 0.9344 - val_loss: 0.4549 - val_acc: 0.8970
#
# Epoch 00065: val_acc did not improve from 0.90580
# Epoch 66/100
# Learning rate:  0.0002
#  - 80s - loss: 0.3001 - acc: 0.9358 - val_loss: 0.4174 - val_acc: 0.9083
#
# Epoch 00066: val_acc improved from 0.90580 to 0.90830, saving model to cifar10-resnet1-best.h5
# Epoch 67/100
# Learning rate:  0.0002
#  - 80s - loss: 0.2950 - acc: 0.9368 - val_loss: 0.4753 - val_acc: 0.8953
#
# Epoch 00067: val_acc did not improve from 0.90830
# Epoch 68/100
# Learning rate:  0.0002
#  - 80s - loss: 0.2931 - acc: 0.9359 - val_loss: 0.4338 - val_acc: 0.9052
#
# Epoch 00068: val_acc did not improve from 0.90830
# Epoch 69/100
# Learning rate:  0.0002
#  - 80s - loss: 0.2894 - acc: 0.9379 - val_loss: 0.4522 - val_acc: 0.9010
#
# Epoch 00069: val_acc did not improve from 0.90830
# Epoch 70/100
# Learning rate:  0.0002
#  - 80s - loss: 0.2856 - acc: 0.9387 - val_loss: 0.4185 - val_acc: 0.9077
#
# Epoch 00070: val_acc did not improve from 0.90830
# Epoch 71/100
# Learning rate:  0.0002
#  - 80s - loss: 0.2836 - acc: 0.9385 - val_loss: 0.4343 - val_acc: 0.9042
#
# Epoch 00071: val_acc did not improve from 0.90830
# Epoch 72/100
# Learning rate:  0.0002
#  - 81s - loss: 0.2867 - acc: 0.9374 - val_loss: 0.4292 - val_acc: 0.9066
#
# Epoch 00072: val_acc did not improve from 0.90830
# Epoch 73/100
# Learning rate:  0.0002
#  - 81s - loss: 0.2817 - acc: 0.9393 - val_loss: 0.4608 - val_acc: 0.8955
#
# Epoch 00073: val_acc did not improve from 0.90830
# Epoch 74/100
# Learning rate:  0.0002
#  - 81s - loss: 0.2765 - acc: 0.9403 - val_loss: 0.4526 - val_acc: 0.9053
#
# Epoch 00074: val_acc did not improve from 0.90830
# Epoch 75/100
# Learning rate:  0.0002
#  - 81s - loss: 0.2767 - acc: 0.9399 - val_loss: 0.4874 - val_acc: 0.8907
#
# Epoch 00075: val_acc did not improve from 0.90830
# Epoch 76/100
# Learning rate:  0.0002
#  - 80s - loss: 0.2741 - acc: 0.9406 - val_loss: 0.4623 - val_acc: 0.8989
#
# Epoch 00076: val_acc did not improve from 0.90830
# Epoch 77/100
# Learning rate:  0.0002
#  - 80s - loss: 0.2769 - acc: 0.9407 - val_loss: 0.4407 - val_acc: 0.8993
#
# Epoch 00077: val_acc did not improve from 0.90830
# Epoch 78/100
# Learning rate:  0.0002
#  - 80s - loss: 0.2740 - acc: 0.9398 - val_loss: 0.4619 - val_acc: 0.8993
#
# Epoch 00078: val_acc did not improve from 0.90830
# Epoch 79/100
# Learning rate:  0.0002
#  - 80s - loss: 0.2712 - acc: 0.9406 - val_loss: 0.5028 - val_acc: 0.8868
#
# Epoch 00079: val_acc did not improve from 0.90830
# Epoch 80/100
# Learning rate:  0.0002
#  - 80s - loss: 0.2702 - acc: 0.9405 - val_loss: 0.4734 - val_acc: 0.8971
#
# Epoch 00080: val_acc did not improve from 0.90830
# Epoch 81/100
# Learning rate:  0.0002
#  - 80s - loss: 0.2662 - acc: 0.9418 - val_loss: 0.4534 - val_acc: 0.8984
#
# Epoch 00081: val_acc did not improve from 0.90830
# Epoch 82/100
# Learning rate:  0.0001
#  - 81s - loss: 0.2532 - acc: 0.9465 - val_loss: 0.4200 - val_acc: 0.9084
#
# Epoch 00082: val_acc improved from 0.90830 to 0.90840, saving model to cifar10-resnet1-best.h5
# Epoch 83/100
# Learning rate:  0.0001
#  - 81s - loss: 0.2482 - acc: 0.9490 - val_loss: 0.4115 - val_acc: 0.9103
#
# Epoch 00083: val_acc improved from 0.90840 to 0.91030, saving model to cifar10-resnet1-best.h5
# Epoch 84/100
# Learning rate:  0.0001
#  - 80s - loss: 0.2459 - acc: 0.9490 - val_loss: 0.4392 - val_acc: 0.9074
#
# Epoch 00084: val_acc did not improve from 0.91030
# Epoch 85/100
# Learning rate:  0.0001
#  - 80s - loss: 0.2445 - acc: 0.9494 - val_loss: 0.4258 - val_acc: 0.9066
#
# Epoch 00085: val_acc did not improve from 0.91030
# Epoch 86/100
# Learning rate:  0.0001
#  - 80s - loss: 0.2406 - acc: 0.9500 - val_loss: 0.4297 - val_acc: 0.9100
#
# Epoch 00086: val_acc did not improve from 0.91030
# Epoch 87/100
# Learning rate:  0.0001
#  - 80s - loss: 0.2401 - acc: 0.9506 - val_loss: 0.3967 - val_acc: 0.9146
#
# Epoch 00087: val_acc improved from 0.91030 to 0.91460, saving model to cifar10-resnet1-best.h5
# Epoch 88/100
# Learning rate:  0.0001
#  - 80s - loss: 0.2392 - acc: 0.9506 - val_loss: 0.4238 - val_acc: 0.9068
#
# Epoch 00088: val_acc did not improve from 0.91460
# Epoch 89/100
# Learning rate:  0.0001
#  - 80s - loss: 0.2391 - acc: 0.9507 - val_loss: 0.4016 - val_acc: 0.9115
#
# Epoch 00089: val_acc did not improve from 0.91460
# Epoch 90/100
# Learning rate:  0.0001
#  - 81s - loss: 0.2363 - acc: 0.9508 - val_loss: 0.4406 - val_acc: 0.9075
#
# Epoch 00090: val_acc did not improve from 0.91460
# Epoch 91/100
# Learning rate:  0.0001
#  - 80s - loss: 0.2344 - acc: 0.9513 - val_loss: 0.4024 - val_acc: 0.9126
#
# Epoch 00091: val_acc did not improve from 0.91460
# Epoch 92/100
# Learning rate:  3e-05
#  - 80s - loss: 0.2249 - acc: 0.9548 - val_loss: 0.3973 - val_acc: 0.9167
#
# Epoch 00092: val_acc improved from 0.91460 to 0.91670, saving model to cifar10-resnet1-best.h5
# Epoch 93/100
# Learning rate:  3e-05
#  - 80s - loss: 0.2235 - acc: 0.9553 - val_loss: 0.3916 - val_acc: 0.9155
#
# Epoch 00093: val_acc did not improve from 0.91670
# Epoch 94/100
# Learning rate:  3e-05
#  - 80s - loss: 0.2225 - acc: 0.9564 - val_loss: 0.4031 - val_acc: 0.9155
#
# Epoch 00094: val_acc did not improve from 0.91670
# Epoch 95/100
# Learning rate:  3e-05
#  - 80s - loss: 0.2188 - acc: 0.9571 - val_loss: 0.4057 - val_acc: 0.9139
#
# Epoch 00095: val_acc did not improve from 0.91670
# Epoch 96/100
# Learning rate:  3e-05
#  - 81s - loss: 0.2214 - acc: 0.9561 - val_loss: 0.3966 - val_acc: 0.9151
#
# Epoch 00096: val_acc did not improve from 0.91670
# Epoch 97/100
# Learning rate:  3e-05
#  - 81s - loss: 0.2183 - acc: 0.9563 - val_loss: 0.4072 - val_acc: 0.9145
#
# Epoch 00097: val_acc did not improve from 0.91670
# Epoch 98/100
# Learning rate:  3e-05
#  - 80s - loss: 0.2171 - acc: 0.9576 - val_loss: 0.4079 - val_acc: 0.9142
#
# Epoch 00098: val_acc did not improve from 0.91670
# Epoch 99/100
# Learning rate:  3e-05
#  - 80s - loss: 0.2156 - acc: 0.9581 - val_loss: 0.3895 - val_acc: 0.9183
#
# Epoch 00099: val_acc improved from 0.91670 to 0.91830, saving model to cifar10-resnet1-best.h5
# Epoch 100/100
# Learning rate:  3e-05
#  - 81s - loss: 0.2157 - acc: 0.9576 - val_loss: 0.4005 - val_acc: 0.9150
#
# Epoch 00100: val_acc did not improve from 0.91830

# %% [markdown]
# # Results

# %%
model.load_weights('cifar10-resnet1-best.h5')

# %%
# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=2)
print('Test loss: {:.5f}'.format(scores[0]))
print('Test accuracy: {:.2%}'.format(scores[1]))
# Out:
# Test loss: 0.38953
# Test accuracy: 91.83%

# %%
plt.plot(hist.history['val_acc'],label='val_acc')
plt.plot(hist.history['acc'],label='acc')
plt.legend()
plt.show()

# %%
np.max(hist.history['val_acc'])
# Out:
# 0.9183
