# %% [markdown]
# <a href="https://colab.research.google.com/github/ispapadakis/cifar10/blob/master/CIFAR_10_RESNETv2c_No_Noise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIFAR-10 Analysis - No Noise
#
# ---
#
# - Architecture: Resnet
# - Data Augmentation: Full range of options as long as no Noise or Cutout (Horizontal Flip, Rotate, Shift, Zoom, Shear, Color Balance)
# - Config B: New LR Schedule
#
# <p> Based On: https://github.com/keras-team/keras/blob/master/examples/cifar10_resnet.py

# %% [markdown]
# # Load Data and Libraries

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10

import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
# Out:
# Using TensorFlow backend.

# %%
# Training parameters
batch_size = 128  # orig paper trained all networks with batch_size=128
epochs = 100
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# %%
n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 2

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# %%
# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# %%
# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# # Model Architecture

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder
    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)
    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]
    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M
    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]
    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256
    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule
    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.
    # Arguments
        epoch (int): The number of epochs
    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 90:
        lr *= 0.03
    elif epoch > 80:
        lr *= 0.1
    elif epoch > 60:
        lr *= 0.2
    elif epoch > 40:
        lr *= 0.5
    print('Learning rate: ', lr)
    return lr

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)
# Out:
# Learning rate:  0.001
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 32, 32, 16)   448         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 32, 32, 16)   64          conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 32, 32, 16)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 32, 32, 16)   272         activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 32, 32, 16)   64          conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 32, 32, 16)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 32, 32, 16)   2320        activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 32, 32, 16)   64          conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 32, 32, 16)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 32, 32, 64)   1088        activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 32, 32, 64)   1088        activation_59[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 32, 32, 64)   0           conv2d_67[0][0]
#                                                                  conv2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 32, 32, 64)   256         add_19[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 32, 32, 64)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 32, 32, 16)   1040        activation_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 32, 32, 16)   64          conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 32, 32, 16)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 32, 32, 16)   2320        activation_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 32, 32, 16)   64          conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 32, 32, 16)   0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 32, 32, 64)   1088        activation_62[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 32, 32, 64)   0           add_19[0][0]
#                                                                  conv2d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 32, 32, 64)   256         add_20[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 32, 32, 64)   0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 32, 32, 16)   1040        activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 32, 32, 16)   64          conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 32, 32, 16)   0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 32, 32, 16)   2320        activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 32, 32, 16)   64          conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 32, 32, 16)   0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 32, 32, 64)   1088        activation_65[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 32, 32, 64)   0           add_20[0][0]
#                                                                  conv2d_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 32, 32, 64)   256         add_21[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 32, 32, 64)   0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 16, 16, 64)   4160        activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 16, 16, 64)   256         conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 16, 16, 64)   0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 16, 16, 64)   36928       activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 16, 16, 64)   256         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 16, 16, 64)   0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 16, 16, 128)  8320        add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 16, 16, 128)  8320        activation_68[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 16, 16, 128)  0           conv2d_77[0][0]
#                                                                  conv2d_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 16, 16, 128)  512         add_22[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 16, 16, 128)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 16, 16, 64)   8256        activation_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 16, 16, 64)   256         conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 16, 16, 64)   0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 16, 16, 64)   36928       activation_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 16, 16, 64)   256         conv2d_79[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 16, 16, 64)   0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 16, 16, 128)  8320        activation_71[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 16, 16, 128)  0           add_22[0][0]
#                                                                  conv2d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 16, 16, 128)  512         add_23[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 16, 16, 128)  0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 16, 16, 64)   8256        activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 16, 16, 64)   256         conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 16, 16, 64)   0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 16, 16, 64)   36928       activation_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 16, 16, 64)   256         conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 16, 16, 64)   0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 16, 16, 128)  8320        activation_74[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 16, 16, 128)  0           add_23[0][0]
#                                                                  conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 16, 16, 128)  512         add_24[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 16, 16, 128)  0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 128)    16512       activation_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 128)    512         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 128)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 128)    147584      activation_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 128)    512         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 128)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 256)    33024       add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 256)    33024       activation_77[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 8, 8, 256)    0           conv2d_87[0][0]
#                                                                  conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 256)    1024        add_25[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 256)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 128)    32896       activation_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 128)    512         conv2d_88[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 128)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 128)    147584      activation_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 128)    512         conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 128)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 256)    33024       activation_80[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 8, 8, 256)    0           add_25[0][0]
#                                                                  conv2d_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 256)    1024        add_26[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 256)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 128)    32896       activation_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 128)    512         conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 128)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 128)    147584      activation_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 128)    512         conv2d_92[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 128)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 256)    33024       activation_83[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 8, 8, 256)    0           add_26[0][0]
#                                                                  conv2d_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 256)    1024        add_27[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 256)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 1, 1, 256)    0           activation_84[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 256)          0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           2570        flatten_3[0][0]
# ==================================================================================================
# Total params: 849,002
# Trainable params: 843,786
# Non-trainable params: 5,216
# __________________________________________________________________________________________________
# ResNet29v2

# %% [markdown]
# # Train Model

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
fname = 'cifar10-resnet{}-best.h5'.format(version)
checkpoint = ModelCheckpoint(filepath=fname,
                             monitor='val_acc', verbose=2, 
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
#data augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    zoom_range=[0.8,1.4],
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False,
    #brightness_range=[.5,1.5], 
    shear_range=15,
    channel_shift_range=0.5,
    fill_mode='nearest'
    )
datagen.fit(x_train)

# %%
# Fit the model on the batches generated by datagen.flow().
hist = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=2*x_train.shape[0]//batch_size,
                    validation_data=(x_test, y_test),
                    epochs=epochs, verbose=2, callbacks=callbacks)
# Out:
# Epoch 1/100
# Learning rate:  0.001
#  - 174s - loss: 2.0517 - acc: 0.4193 - val_loss: 2.1366 - val_acc: 0.4302
#
# Epoch 00001: val_acc improved from -inf to 0.43020, saving model to cifar10-resnet2-best.h5
# Epoch 2/100
# Learning rate:  0.001
#  - 162s - loss: 1.6090 - acc: 0.5408 - val_loss: 1.3760 - val_acc: 0.6183
#
# Epoch 00002: val_acc improved from 0.43020 to 0.61830, saving model to cifar10-resnet2-best.h5
# Epoch 3/100
# Learning rate:  0.001
#  - 161s - loss: 1.4046 - acc: 0.6066 - val_loss: 1.6869 - val_acc: 0.5844
#
# Epoch 00003: val_acc did not improve from 0.61830
# Epoch 4/100
# Learning rate:  0.001
#  - 162s - loss: 1.2741 - acc: 0.6482 - val_loss: 1.6071 - val_acc: 0.5848
#
# Epoch 00004: val_acc did not improve from 0.61830
# Epoch 5/100
# Learning rate:  0.001
#  - 162s - loss: 1.1861 - acc: 0.6759 - val_loss: 1.1267 - val_acc: 0.7064
#
# Epoch 00005: val_acc improved from 0.61830 to 0.70640, saving model to cifar10-resnet2-best.h5
# Epoch 6/100
# Learning rate:  0.001
#  - 161s - loss: 1.1231 - acc: 0.6964 - val_loss: 0.9733 - val_acc: 0.7603
#
# Epoch 00006: val_acc improved from 0.70640 to 0.76030, saving model to cifar10-resnet2-best.h5
# Epoch 7/100
# Learning rate:  0.001
#  - 162s - loss: 1.0745 - acc: 0.7130 - val_loss: 1.3259 - val_acc: 0.6895
#
# Epoch 00007: val_acc did not improve from 0.76030
# Epoch 8/100
# Learning rate:  0.001
#  - 162s - loss: 1.0305 - acc: 0.7255 - val_loss: 1.0729 - val_acc: 0.7347
#
# Epoch 00008: val_acc did not improve from 0.76030
# Epoch 9/100
# Learning rate:  0.001
#  - 162s - loss: 1.0022 - acc: 0.7368 - val_loss: 1.0602 - val_acc: 0.7526
#
# Epoch 00009: val_acc did not improve from 0.76030
# Epoch 10/100
# Learning rate:  0.001
#  - 162s - loss: 0.9677 - acc: 0.7470 - val_loss: 1.0397 - val_acc: 0.7540
#
# Epoch 00010: val_acc did not improve from 0.76030
# Epoch 11/100
# Learning rate:  0.001
#  - 162s - loss: 0.9466 - acc: 0.7541 - val_loss: 0.7916 - val_acc: 0.8186
#
# Epoch 00011: val_acc improved from 0.76030 to 0.81860, saving model to cifar10-resnet2-best.h5
# Epoch 12/100
# Learning rate:  0.001
#  - 162s - loss: 0.9277 - acc: 0.7596 - val_loss: 0.7832 - val_acc: 0.8163
#
# Epoch 00012: val_acc did not improve from 0.81860
# Epoch 13/100
# Learning rate:  0.001
#  - 162s - loss: 0.9106 - acc: 0.7649 - val_loss: 0.9475 - val_acc: 0.7868
#
# Epoch 00013: val_acc did not improve from 0.81860
# Epoch 14/100
# Learning rate:  0.001
#  - 161s - loss: 0.8969 - acc: 0.7685 - val_loss: 1.0005 - val_acc: 0.7745
#
# Epoch 00014: val_acc did not improve from 0.81860
# Epoch 15/100
# Learning rate:  0.001
#  - 161s - loss: 0.8797 - acc: 0.7738 - val_loss: 1.0057 - val_acc: 0.7589
#
# Epoch 00015: val_acc did not improve from 0.81860
# Epoch 16/100
# Learning rate:  0.001
#  - 161s - loss: 0.8655 - acc: 0.7777 - val_loss: 0.9741 - val_acc: 0.7728
#
# Epoch 00016: val_acc did not improve from 0.81860
# Epoch 17/100
# Learning rate:  0.001
#  - 161s - loss: 0.8552 - acc: 0.7812 - val_loss: 0.9499 - val_acc: 0.7795
#
# Epoch 00017: val_acc did not improve from 0.81860
# Epoch 18/100
# Learning rate:  0.001
#  - 161s - loss: 0.8410 - acc: 0.7873 - val_loss: 0.8928 - val_acc: 0.7901
#
# Epoch 00018: val_acc did not improve from 0.81860
# Epoch 19/100
# Learning rate:  0.001
#  - 161s - loss: 0.8304 - acc: 0.7911 - val_loss: 0.7612 - val_acc: 0.8202
#
# Epoch 00019: val_acc improved from 0.81860 to 0.82020, saving model to cifar10-resnet2-best.h5
# Epoch 20/100
# Learning rate:  0.001
#  - 162s - loss: 0.8251 - acc: 0.7905 - val_loss: 0.8318 - val_acc: 0.8139
#
# Epoch 00020: val_acc did not improve from 0.82020
# Epoch 21/100
# Learning rate:  0.001
#  - 161s - loss: 0.8140 - acc: 0.7951 - val_loss: 0.7021 - val_acc: 0.8405
#
# Epoch 00021: val_acc improved from 0.82020 to 0.84050, saving model to cifar10-resnet2-best.h5
# Epoch 22/100
# Learning rate:  0.001
#  - 162s - loss: 0.8085 - acc: 0.7975 - val_loss: 0.7943 - val_acc: 0.8222
#
# Epoch 00022: val_acc did not improve from 0.84050
# Epoch 23/100
# Learning rate:  0.001
#  - 162s - loss: 0.7976 - acc: 0.8013 - val_loss: 0.7756 - val_acc: 0.8265
#
# Epoch 00023: val_acc did not improve from 0.84050
# Epoch 24/100
# Learning rate:  0.001
#  - 162s - loss: 0.7888 - acc: 0.8037 - val_loss: 0.7895 - val_acc: 0.8298
#
# Epoch 00024: val_acc did not improve from 0.84050
# Epoch 25/100
# Learning rate:  0.001
#  - 162s - loss: 0.7853 - acc: 0.8044 - val_loss: 0.6582 - val_acc: 0.8585
#
# Epoch 00025: val_acc improved from 0.84050 to 0.85850, saving model to cifar10-resnet2-best.h5
# Epoch 26/100
# Learning rate:  0.001
#  - 162s - loss: 0.7823 - acc: 0.8067 - val_loss: 0.7639 - val_acc: 0.8236
#
# Epoch 00026: val_acc did not improve from 0.85850
# Epoch 27/100
# Learning rate:  0.001
#  - 162s - loss: 0.7706 - acc: 0.8094 - val_loss: 0.8821 - val_acc: 0.8016
#
# Epoch 00027: val_acc did not improve from 0.85850
# Epoch 28/100
# Learning rate:  0.001
#  - 162s - loss: 0.7655 - acc: 0.8116 - val_loss: 0.7562 - val_acc: 0.8302
#
# Epoch 00028: val_acc did not improve from 0.85850
# Epoch 29/100
# Learning rate:  0.001
#  - 163s - loss: 0.7587 - acc: 0.8131 - val_loss: 0.7257 - val_acc: 0.8340
#
# Epoch 00029: val_acc did not improve from 0.85850
# Epoch 30/100
# Learning rate:  0.001
#  - 163s - loss: 0.7588 - acc: 0.8139 - val_loss: 0.6990 - val_acc: 0.8488
#
# Epoch 00030: val_acc did not improve from 0.85850
# Epoch 31/100
# Learning rate:  0.001
#  - 162s - loss: 0.7500 - acc: 0.8168 - val_loss: 0.7297 - val_acc: 0.8376
#
# Epoch 00031: val_acc did not improve from 0.85850
# Epoch 32/100
# Learning rate:  0.001
#  - 162s - loss: 0.7469 - acc: 0.8165 - val_loss: 0.7281 - val_acc: 0.8397
#
# Epoch 00032: val_acc did not improve from 0.85850
# Epoch 33/100
# Learning rate:  0.001
#  - 162s - loss: 0.7369 - acc: 0.8200 - val_loss: 0.8160 - val_acc: 0.8249
#
# Epoch 00033: val_acc did not improve from 0.85850
# Epoch 34/100
# Learning rate:  0.001
#  - 162s - loss: 0.7365 - acc: 0.8210 - val_loss: 0.7877 - val_acc: 0.8147
#
# Epoch 00034: val_acc did not improve from 0.85850
# Epoch 35/100
# Learning rate:  0.001
#  - 162s - loss: 0.7336 - acc: 0.8196 - val_loss: 0.7082 - val_acc: 0.8399
#
# Epoch 00035: val_acc did not improve from 0.85850
# Epoch 36/100
# Learning rate:  0.001
#  - 162s - loss: 0.7255 - acc: 0.8228 - val_loss: 0.7162 - val_acc: 0.8415
#
# Epoch 00036: val_acc did not improve from 0.85850
# Epoch 37/100
# Learning rate:  0.001
#  - 162s - loss: 0.7212 - acc: 0.8247 - val_loss: 0.6769 - val_acc: 0.8507
#
# Epoch 00037: val_acc did not improve from 0.85850
# Epoch 38/100
# Learning rate:  0.001
#  - 161s - loss: 0.7200 - acc: 0.8258 - val_loss: 0.6338 - val_acc: 0.8618
#
# Epoch 00038: val_acc improved from 0.85850 to 0.86180, saving model to cifar10-resnet2-best.h5
# Epoch 39/100
# Learning rate:  0.001
#  - 162s - loss: 0.7161 - acc: 0.8264 - val_loss: 0.6452 - val_acc: 0.8599
#
# Epoch 00039: val_acc did not improve from 0.86180
# Epoch 40/100
# Learning rate:  0.001
#  - 162s - loss: 0.7124 - acc: 0.8282 - val_loss: 0.6904 - val_acc: 0.8514
#
# Epoch 00040: val_acc did not improve from 0.86180
# Epoch 41/100
# Learning rate:  0.001
#  - 162s - loss: 0.7064 - acc: 0.8299 - val_loss: 0.7641 - val_acc: 0.8429
#
# Epoch 00041: val_acc did not improve from 0.86180
# Epoch 42/100
# Learning rate:  0.0005
#  - 162s - loss: 0.6300 - acc: 0.8548 - val_loss: 0.6135 - val_acc: 0.8742
#
# Epoch 00042: val_acc improved from 0.86180 to 0.87420, saving model to cifar10-resnet2-best.h5
# Epoch 43/100
# Learning rate:  0.0005
#  - 162s - loss: 0.6115 - acc: 0.8582 - val_loss: 0.5938 - val_acc: 0.8797
#
# Epoch 00043: val_acc improved from 0.87420 to 0.87970, saving model to cifar10-resnet2-best.h5
# Epoch 44/100
# Learning rate:  0.0005
#  - 162s - loss: 0.5964 - acc: 0.8611 - val_loss: 0.5436 - val_acc: 0.8884
#
# Epoch 00044: val_acc improved from 0.87970 to 0.88840, saving model to cifar10-resnet2-best.h5
# Epoch 45/100
# Learning rate:  0.0005
#  - 162s - loss: 0.5824 - acc: 0.8649 - val_loss: 0.5446 - val_acc: 0.8889
#
# Epoch 00045: val_acc improved from 0.88840 to 0.88890, saving model to cifar10-resnet2-best.h5
# Epoch 46/100
# Learning rate:  0.0005
#  - 162s - loss: 0.5773 - acc: 0.8645 - val_loss: 0.5580 - val_acc: 0.8825
#
# Epoch 00046: val_acc did not improve from 0.88890
# Epoch 47/100
# Learning rate:  0.0005
#  - 162s - loss: 0.5713 - acc: 0.8665 - val_loss: 0.5496 - val_acc: 0.8875
#
# Epoch 00047: val_acc did not improve from 0.88890
# Epoch 48/100
# Learning rate:  0.0005
#  - 161s - loss: 0.5635 - acc: 0.8673 - val_loss: 0.6360 - val_acc: 0.8698
#
# Epoch 00048: val_acc did not improve from 0.88890
# Epoch 49/100
# Learning rate:  0.0005
#  - 162s - loss: 0.5581 - acc: 0.8689 - val_loss: 0.4925 - val_acc: 0.8998
#
# Epoch 00049: val_acc improved from 0.88890 to 0.89980, saving model to cifar10-resnet2-best.h5
# Epoch 50/100
# Learning rate:  0.0005
#  - 163s - loss: 0.5561 - acc: 0.8678 - val_loss: 0.5351 - val_acc: 0.8915
#
# Epoch 00050: val_acc did not improve from 0.89980
# Epoch 51/100
# Learning rate:  0.0005
#  - 163s - loss: 0.5494 - acc: 0.8708 - val_loss: 0.5989 - val_acc: 0.8695
#
# Epoch 00051: val_acc did not improve from 0.89980
# Epoch 52/100
# Learning rate:  0.0005
#  - 162s - loss: 0.5476 - acc: 0.8699 - val_loss: 0.4741 - val_acc: 0.9029
#
# Epoch 00052: val_acc improved from 0.89980 to 0.90290, saving model to cifar10-resnet2-best.h5
# Epoch 53/100
# Learning rate:  0.0005
#  - 162s - loss: 0.5414 - acc: 0.8718 - val_loss: 0.5526 - val_acc: 0.8857
#
# Epoch 00053: val_acc did not improve from 0.90290
# Epoch 54/100
# Learning rate:  0.0005
#  - 162s - loss: 0.5409 - acc: 0.8706 - val_loss: 0.5118 - val_acc: 0.8948
#
# Epoch 00054: val_acc did not improve from 0.90290
# Epoch 55/100
# Learning rate:  0.0005
#  - 162s - loss: 0.5379 - acc: 0.8723 - val_loss: 0.5393 - val_acc: 0.8864
#
# Epoch 00055: val_acc did not improve from 0.90290
# Epoch 56/100
# Learning rate:  0.0005
#  - 162s - loss: 0.5397 - acc: 0.8725 - val_loss: 0.5844 - val_acc: 0.8741
#
# Epoch 00056: val_acc did not improve from 0.90290
# Epoch 57/100
# Learning rate:  0.0005
#  - 162s - loss: 0.5335 - acc: 0.8746 - val_loss: 0.5513 - val_acc: 0.8852
#
# Epoch 00057: val_acc did not improve from 0.90290
# Epoch 58/100
# Learning rate:  0.0005
#  - 162s - loss: 0.5315 - acc: 0.8722 - val_loss: 0.5357 - val_acc: 0.8848
#
# Epoch 00058: val_acc did not improve from 0.90290
# Epoch 59/100
# Learning rate:  0.0005
#  - 162s - loss: 0.5276 - acc: 0.8745 - val_loss: 0.4905 - val_acc: 0.9012
#
# Epoch 00059: val_acc did not improve from 0.90290
# Epoch 60/100
# Learning rate:  0.0005
#  - 162s - loss: 0.5290 - acc: 0.8743 - val_loss: 0.4937 - val_acc: 0.8983
#
# Epoch 00060: val_acc did not improve from 0.90290
# Epoch 61/100
# Learning rate:  0.0005
#  - 162s - loss: 0.5238 - acc: 0.8753 - val_loss: 0.5162 - val_acc: 0.8888
#
# Epoch 00061: val_acc did not improve from 0.90290
# Epoch 62/100
# Learning rate:  0.0002
#  - 163s - loss: 0.4703 - acc: 0.8938 - val_loss: 0.4264 - val_acc: 0.9171
#
# Epoch 00062: val_acc improved from 0.90290 to 0.91710, saving model to cifar10-resnet2-best.h5
# Epoch 63/100
# Learning rate:  0.0002
#  - 162s - loss: 0.4538 - acc: 0.8988 - val_loss: 0.4565 - val_acc: 0.9119
#
# Epoch 00063: val_acc did not improve from 0.91710
# Epoch 64/100
# Learning rate:  0.0002
#  - 162s - loss: 0.4482 - acc: 0.8993 - val_loss: 0.4611 - val_acc: 0.9095
#
# Epoch 00064: val_acc did not improve from 0.91710
# Epoch 65/100
# Learning rate:  0.0002
#  - 162s - loss: 0.4436 - acc: 0.9003 - val_loss: 0.4339 - val_acc: 0.9153
#
# Epoch 00065: val_acc did not improve from 0.91710
# Epoch 66/100
# Learning rate:  0.0002
#  - 162s - loss: 0.4397 - acc: 0.9008 - val_loss: 0.4425 - val_acc: 0.9148
#
# Epoch 00066: val_acc did not improve from 0.91710
# Epoch 67/100
# Learning rate:  0.0002
#  - 162s - loss: 0.4270 - acc: 0.9038 - val_loss: 0.4054 - val_acc: 0.9209
#
# Epoch 00067: val_acc improved from 0.91710 to 0.92090, saving model to cifar10-resnet2-best.h5
# Epoch 68/100
# Learning rate:  0.0002
#  - 162s - loss: 0.4261 - acc: 0.9041 - val_loss: 0.4330 - val_acc: 0.9167
#
# Epoch 00068: val_acc did not improve from 0.92090
# Epoch 69/100
# Learning rate:  0.0002
#  - 162s - loss: 0.4220 - acc: 0.9051 - val_loss: 0.4299 - val_acc: 0.9180
#
# Epoch 00069: val_acc did not improve from 0.92090
# Epoch 70/100
# Learning rate:  0.0002
#  - 162s - loss: 0.4155 - acc: 0.9074 - val_loss: 0.4250 - val_acc: 0.9171
#
# Epoch 00070: val_acc did not improve from 0.92090
# Epoch 71/100
# Learning rate:  0.0002
#  - 161s - loss: 0.4150 - acc: 0.9071 - val_loss: 0.3956 - val_acc: 0.9237
#
# Epoch 00071: val_acc improved from 0.92090 to 0.92370, saving model to cifar10-resnet2-best.h5
# Epoch 72/100
# Learning rate:  0.0002
#  - 162s - loss: 0.4122 - acc: 0.9068 - val_loss: 0.4337 - val_acc: 0.9146
#
# Epoch 00072: val_acc did not improve from 0.92370
# Epoch 73/100
# Learning rate:  0.0002
#  - 163s - loss: 0.4095 - acc: 0.9075 - val_loss: 0.4115 - val_acc: 0.9179
#
# Epoch 00073: val_acc did not improve from 0.92370
# Epoch 74/100
# Learning rate:  0.0002
#  - 161s - loss: 0.4048 - acc: 0.9091 - val_loss: 0.4338 - val_acc: 0.9145
#
# Epoch 00074: val_acc did not improve from 0.92370
# Epoch 75/100
# Learning rate:  0.0002
#  - 161s - loss: 0.4021 - acc: 0.9094 - val_loss: 0.4391 - val_acc: 0.9137
#
# Epoch 00075: val_acc did not improve from 0.92370
# Epoch 76/100
# Learning rate:  0.0002
#  - 161s - loss: 0.4041 - acc: 0.9085 - val_loss: 0.4397 - val_acc: 0.9156
#
# Epoch 00076: val_acc did not improve from 0.92370
# Epoch 77/100
# Learning rate:  0.0002
#  - 161s - loss: 0.3997 - acc: 0.9091 - val_loss: 0.3910 - val_acc: 0.9241
#
# Epoch 00077: val_acc improved from 0.92370 to 0.92410, saving model to cifar10-resnet2-best.h5
# Epoch 78/100
# Learning rate:  0.0002
#  - 161s - loss: 0.3903 - acc: 0.9123 - val_loss: 0.4334 - val_acc: 0.9170
#
# Epoch 00078: val_acc did not improve from 0.92410
# Epoch 79/100
# Learning rate:  0.0002
#  - 161s - loss: 0.3945 - acc: 0.9096 - val_loss: 0.4191 - val_acc: 0.9170
#
# Epoch 00079: val_acc did not improve from 0.92410
# Epoch 80/100
# Learning rate:  0.0002
#  - 161s - loss: 0.3919 - acc: 0.9120 - val_loss: 0.4282 - val_acc: 0.9184
#
# Epoch 00080: val_acc did not improve from 0.92410
# Epoch 81/100
# Learning rate:  0.0002
#  - 161s - loss: 0.3898 - acc: 0.9116 - val_loss: 0.4337 - val_acc: 0.9147
#
# Epoch 00081: val_acc did not improve from 0.92410
# Epoch 82/100
# Learning rate:  0.0001
#  - 161s - loss: 0.3707 - acc: 0.9186 - val_loss: 0.4130 - val_acc: 0.9211
#
# Epoch 00082: val_acc did not improve from 0.92410
# Epoch 83/100
# Learning rate:  0.0001
#  - 162s - loss: 0.3624 - acc: 0.9215 - val_loss: 0.4271 - val_acc: 0.9186
#
# Epoch 00083: val_acc did not improve from 0.92410
# Epoch 84/100
# Learning rate:  0.0001
#  - 162s - loss: 0.3576 - acc: 0.9223 - val_loss: 0.3988 - val_acc: 0.9226
#
# Epoch 00084: val_acc did not improve from 0.92410
# Epoch 85/100
# Learning rate:  0.0001
#  - 161s - loss: 0.3554 - acc: 0.9228 - val_loss: 0.4134 - val_acc: 0.9198
#
# Epoch 00085: val_acc did not improve from 0.92410
# Epoch 86/100
# Learning rate:  0.0001
#  - 162s - loss: 0.3529 - acc: 0.9234 - val_loss: 0.4050 - val_acc: 0.9220
#
# Epoch 00086: val_acc did not improve from 0.92410
# Epoch 87/100
# Learning rate:  0.0001
#  - 161s - loss: 0.3506 - acc: 0.9238 - val_loss: 0.4093 - val_acc: 0.9238
#
# Epoch 00087: val_acc did not improve from 0.92410
# Epoch 88/100
# Learning rate:  0.0001
#  - 160s - loss: 0.3500 - acc: 0.9244 - val_loss: 0.4172 - val_acc: 0.9199
#
# Epoch 00088: val_acc did not improve from 0.92410
# Epoch 89/100
# Learning rate:  0.0001
#  - 159s - loss: 0.3473 - acc: 0.9244 - val_loss: 0.4020 - val_acc: 0.9225
#
# Epoch 00089: val_acc did not improve from 0.92410
# Epoch 90/100
# Learning rate:  0.0001
#  - 159s - loss: 0.3440 - acc: 0.9251 - val_loss: 0.4054 - val_acc: 0.9215
#
# Epoch 00090: val_acc did not improve from 0.92410
# Epoch 91/100
# Learning rate:  0.0001
#  - 160s - loss: 0.3433 - acc: 0.9254 - val_loss: 0.4156 - val_acc: 0.9202
#
# Epoch 00091: val_acc did not improve from 0.92410
# Epoch 92/100
# Learning rate:  3e-05
#  - 160s - loss: 0.3291 - acc: 0.9303 - val_loss: 0.3709 - val_acc: 0.9305
#
# Epoch 00092: val_acc improved from 0.92410 to 0.93050, saving model to cifar10-resnet2-best.h5
# Epoch 93/100
# Learning rate:  3e-05
#  - 160s - loss: 0.3234 - acc: 0.9325 - val_loss: 0.3784 - val_acc: 0.9286
#
# Epoch 00093: val_acc did not improve from 0.93050
# Epoch 94/100
# Learning rate:  3e-05
#  - 160s - loss: 0.3227 - acc: 0.9328 - val_loss: 0.3752 - val_acc: 0.9308
#
# Epoch 00094: val_acc improved from 0.93050 to 0.93080, saving model to cifar10-resnet2-best.h5
# Epoch 95/100
# Learning rate:  3e-05
#  - 160s - loss: 0.3205 - acc: 0.9332 - val_loss: 0.3816 - val_acc: 0.9282
#
# Epoch 00095: val_acc did not improve from 0.93080
# Epoch 96/100
# Learning rate:  3e-05
#  - 160s - loss: 0.3175 - acc: 0.9346 - val_loss: 0.3710 - val_acc: 0.9318
#
# Epoch 00096: val_acc improved from 0.93080 to 0.93180, saving model to cifar10-resnet2-best.h5
# Epoch 97/100
# Learning rate:  3e-05
#  - 160s - loss: 0.3177 - acc: 0.9343 - val_loss: 0.3735 - val_acc: 0.9308
#
# Epoch 00097: val_acc did not improve from 0.93180
# Epoch 98/100
# Learning rate:  3e-05
#  - 161s - loss: 0.3189 - acc: 0.9341 - val_loss: 0.3697 - val_acc: 0.9326
#
# Epoch 00098: val_acc improved from 0.93180 to 0.93260, saving model to cifar10-resnet2-best.h5
# Epoch 99/100
# Learning rate:  3e-05
#  - 161s - loss: 0.3123 - acc: 0.9356 - val_loss: 0.3693 - val_acc: 0.9322
#
# Epoch 00099: val_acc did not improve from 0.93260
# Epoch 100/100
# Learning rate:  3e-05
#  - 162s - loss: 0.3159 - acc: 0.9343 - val_loss: 0.3673 - val_acc: 0.9322
#
# Epoch 00100: val_acc did not improve from 0.93260

# %% [markdown]
# # Results

# %%
plt.plot(hist.history['val_acc'],label='val_acc')
plt.plot(hist.history['acc'],label='acc')
plt.legend()
plt.show()

# %%
np.max(hist.history['val_acc'])
# Out:
# 0.9326
