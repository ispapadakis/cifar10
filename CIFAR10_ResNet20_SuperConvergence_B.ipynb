# %% [markdown]
# <a href="https://colab.research.google.com/github/ispapadakis/cifar10/blob/master/CIFAR10_ResNet20_SuperConvergence_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIFAR-10 Image Detection
#
# ---
#
# - Architecture: Resnet 20
# - Data Augmentation: Cutout, Horizontal Flip, Shift
# - Revised Schedule for Super Convergence B: Learning Rate and Momentum
#
# <p> Based On: https://github.com/keras-team/keras/blob/master/examples/cifar10_resnet.py

# %% [markdown]
# # Load Data and Libraries

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, MaxPooling2D, Input, Flatten, concatenate
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10

import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
# Out:
# Using TensorFlow backend.

# %%
# Model version
# Orig paper: version = 1 (ResNet v1)

version = 1
n = 3
depth = n * 6 + 2

num_classes = 10

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 34s 0us/step

# %%
# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
x_train_mean = np.mean(x_train, axis=(0,1,2))
x_train -= x_train_mean
x_test -= x_train_mean
x_train_std = np.std(x_train, axis=(0,1,2))
x_train /= x_train_std
x_test  /= x_train_std

print('x_train shape:', x_train.shape)
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# y_train shape: (50000, 1)

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# # Model Architecture

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder
    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)
    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]
    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M
    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)
    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal',
                    kernel_regularizer=l2(1e-4))(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# # Train Model

# %%
hyper = {'lr':0.44,'rho':0.95,'alpha':0.5e-4,'augmentation_factor':6,'batch_size':512}

BATCHES_PER_EPOCH = hyper['augmentation_factor'] * x_train.shape[0] // hyper['batch_size']
BATCHES_PER_EPOCH
# Out:
# 585

# %% [markdown]
# ## Optimizer Settings for Super Convergence

# %%
class SuperConvergence(keras.callbacks.Callback):
  def __init__(self, epoch_domain=[0, 10, 30, 40],
               lr_range = [0, 0.1, 0.005, 0], mtm_range = [.95, 0.85, 0.95, 0.95],
               echo=False):
    super().__init__()
    self.epoch_domain = epoch_domain
    self.lr_range = lr_range
    self.mtm_range = mtm_range
    self.lr_schedule  = lambda step: np.interp(step/BATCHES_PER_EPOCH, self.epoch_domain, self.lr_range)
    self.mtm_schedule = lambda step: np.interp(step/BATCHES_PER_EPOCH, self.epoch_domain, self.mtm_range)
    self.step = 0
    self.echo = echo
    
  def on_batch_begin(self, batch, logs=None):
    keras.backend.set_value(self.model.optimizer.lr, self.lr_schedule(self.step))
    keras.backend.set_value(self.model.optimizer.momentum, self.mtm_schedule(self.step))
    self.step += 1
    
  def on_epoch_end(self, epoch, logs=None):
    if self.echo:
      lr = keras.backend.get_value(self.model.optimizer.lr)
      mtm = keras.backend.get_value(self.model.optimizer.momentum)
      print('Learning Rate: {:.4f} Momentum: {:.2f}'.format(lr,mtm))
  
  def epochs(self):
    return self.epoch_domain[-1]
  
  def __repr__(self):
    s = 'SuperConvergence('
    s += 'epoch_domain={}, '.format(self.epoch_domain)
    s += 'lr_range={}, '.format(self.lr_range)
    s += 'mtm_range={}, '.format(self.mtm_range)
    s += 'echo={})'.format(self.echo)
    return s

# %% [markdown]
# ## Data Augmentation Generator

# %%
def fit_cutout(train_image, channels_last=True, cutout_pxl = 8):
    try:
        shape = train_image.shape
        if train_image.ndim != 3:
            raise Exception('Expecting 3D Image')
    except AttributeError:
        print('Expecting train_image input to be numpy array')
        raise

    if channels_last:
        img_h, img_w, img_c = shape
    else:
        img_c, img_h, img_w = shape
        
    sq_side_half = np.round(cutout_pxl / 2).astype('int')
    
    def preprocess(image):
      
        new_image = image.copy()
        
        h = np.random.randint(img_h)
        w = np.random.randint(img_w)
        
        h_lo = max(0,h-sq_side_half)
        h_hi = min(img_h,h+sq_side_half)
        
        w_lo = max(0,w-sq_side_half)
        w_hi = min(img_w,w+sq_side_half)
        
        value = np.random.uniform(0,1,(3,))

        if channels_last:
            new_image[h_lo:h_hi,w_lo:w_hi,:] = value[np.newaxis,np.newaxis,:]
        else:
            new_image[:,h_lo:h_hi,w_lo:w_hi] = value[:,np.newaxis,np.newaxis]
        return new_image
    return preprocess
  
cutout = fit_cutout(x_train[0])

# %%
#data augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    #zoom_range=[0.8,1.4],
    #rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False,
    #brightness_range=[.15,1.15], 
    #shear_range=15,
    #channel_shift_range=0.2,
    preprocessing_function = cutout,
    fill_mode='reflect'
    )

# %% [markdown]
# ## Model Definition

# %%
def prep_model(lr,rho,alpha,**kwargs):
  keras.backend.clear_session()
  model = resnet_v1(input_shape=input_shape, depth=depth)
  model.compile(loss='categorical_crossentropy',
                optimizer=keras.optimizers.SGD(momentum=rho, nesterov=False, clipvalue = 0.5),
                metrics=['accuracy'])

  for layer in model.layers:
      if isinstance(layer, keras.layers.Conv2D) or isinstance(layer, keras.layers.Dense):
          layer.add_loss(keras.regularizers.l2(alpha)(layer.kernel))
      if hasattr(layer, 'bias_regularizer') and layer.use_bias:
          layer.add_loss(keras.regularizers.l2(alpha)(layer.bias))
          
  rho_diff = rho - 0.90
          
  optim_sched = SuperConvergence(
      epoch_domain = [0, 15, 30, 35], 
      lr_range     = [0, lr, 0.005, 0],
      mtm_range    = [rho, rho - 2 * rho_diff, rho, rho]
  )
  
          
  return model, optim_sched

# %%
model, turbo = prep_model(**hyper)

fig, ax = plt.subplots(1,2,figsize=(12,6))
ax[0].plot(turbo.epoch_domain,turbo.lr_range,'r:')
ax[0].set_title('Learning Rate')
ax[0].set_xlabel('Epoch')

ax[1].plot(turbo.epoch_domain,turbo.mtm_range,'b:')
ax[1].set_title('Momentum')
ax[1].set_xlabel('Epoch')

fig.suptitle('Optimizer Schedules')

plt.show()

# %%
# save as JSON
pickle.dump( model.to_json(), open( model_type+"_model_json.pkl", "wb" ) )

# %% [markdown]
# ## Fit Model

# %%
hist = model.fit_generator(
    datagen.flow(x_train, y_train, batch_size=hyper['batch_size']),
    steps_per_epoch = BATCHES_PER_EPOCH,
    validation_data=(x_test, y_test),
    epochs=turbo.epochs(), verbose=2, 
    callbacks=[turbo]
)
# Out:
# Epoch 1/35
#  - 194s - loss: 0.4528 - acc: 0.9094 - val_loss: 0.7568 - val_acc: 0.8376
# Epoch 26/35
#  - 193s - loss: 0.4299 - acc: 0.9152 - val_loss: 0.6829 - val_acc: 0.8508
# Epoch 27/35
#  - 194s - loss: 0.4052 - acc: 0.9212 - val_loss: 0.6564 - val_acc: 0.8582
# Epoch 28/35
#  - 194s - loss: 0.3686 - acc: 0.9309 - val_loss: 0.5039 - val_acc: 0.8899
# Epoch 29/35
#  - 194s - loss: 0.3239 - acc: 0.9430 - val_loss: 0.5612 - val_acc: 0.8791
# Epoch 30/35
#  - 194s - loss: 0.2692 - acc: 0.9586 - val_loss: 0.4043 - val_acc: 0.9234
# Epoch 31/35
#  - 194s - loss: 0.2326 - acc: 0.9703 - val_loss: 0.3967 - val_acc: 0.9258
# Epoch 32/35
#  - 194s - loss: 0.2237 - acc: 0.9726 - val_loss: 0.3983 - val_acc: 0.9281
# Epoch 33/35
#  - 194s - loss: 0.2184 - acc: 0.9739 - val_loss: 0.4016 - val_acc: 0.9262
# Epoch 34/35
#  - 194s - loss: 0.2138 - acc: 0.9755 - val_loss: 0.3968 - val_acc: 0.9274
# Epoch 35/35
#  - 194s - loss: 0.2120 - acc: 0.9757 - val_loss: 0.3958 - val_acc: 0.9285

# %%
print('Parameters: ',hyper)
pd.DataFrame(hist.history).style.format('{:.4f}').bar(['acc','val_acc'],color='lightgreen').bar(['loss','val_loss'],color='lightblue')
# Out:
# Parameters:  {'lr': 0.44, 'rho': 0.95, 'alpha': 5e-05, 'augmentation_factor': 6, 'batch_size': 512}
# <style  type="text/css" >
#     #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row0_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 100.0%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row0_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 100.0%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 43.2%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 54.5%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 36.9%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 55.5%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 59.8%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 39.4%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 59.2%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 30.2%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 67.2%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 32.5%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 56.2%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 41.1%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 71.6%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 28.6%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 71.2%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 22.8%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 74.5%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 26.1%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 62.8%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 30.2%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 76.5%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 24.8%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 54.1%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 43.8%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 77.7%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 24.0%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 59.8%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row7_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 38.0%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 78.9%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 23.4%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 71.3%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row8_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 28.4%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 79.5%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 23.2%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 66.9%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row9_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 30.1%, transparent 0%);
#         }    #T_3475dd3a_5251_11e9_af8b_0242ac1c0002row10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 79.7%, transparent 0%);

# %%
model.save_weights(model_type+'_weights_B.h5')
